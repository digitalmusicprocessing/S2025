# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np

# %%
x, sr = librosa.load("vocodervocoded.mp3", sr=44100)
S = librosa.stft(x)
plt.imshow(np.abs(S)[0:380, :], cmap='gray')
plt.gca().invert_yaxis()
