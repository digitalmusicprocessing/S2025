# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np

# %%
x, sr = librosa.load("aliensuisei.mp3", sr=44100)
S = librosa.stft(x)
plt.imshow(np.abs(S)[0:200, :], aspect='auto', cmap='gray')
plt.gca().invert_yaxis()
