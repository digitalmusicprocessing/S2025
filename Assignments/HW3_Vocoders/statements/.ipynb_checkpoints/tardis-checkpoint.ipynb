# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np

# %%
x, sr = librosa.load("tardis.mp3", sr=44100)
S = librosa.stft(x)
plt.imshow(np.log10(np.abs(S)[0:400, 0:800]), aspect='auto', cmap='gray')
plt.gca().invert_yaxis()
