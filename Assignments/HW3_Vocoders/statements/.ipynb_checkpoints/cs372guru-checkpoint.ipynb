# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np

# %%
x, sr = librosa.load("cs372guru.mp3", sr=44100)
S = librosa.stft(x)
plt.imshow(np.abs(S)[0:600, :], cmap='gray', aspect='auto')
plt.gca().invert_yaxis()
