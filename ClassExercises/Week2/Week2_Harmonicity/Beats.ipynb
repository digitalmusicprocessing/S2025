# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
t = np.linspace(0, 8, 300)
f1 = 0.2
f2 = 5.2
y = np.cos(2*np.pi*f1*t)# + np.cos(2*np.pi*f2*t)
plt.plot(t, y)

# %%
f1 = 0.2
#y = np.cos(2*np.pi*f1*(t-2))# + np.cos(2*np.pi*f2*t)
y = np.cos(2*np.pi*f1*t - 2.513)
plt.plot(t, y)

# %% [markdown]
# ## $ y(t) = \cos(2 \pi f (t-2)) $
# ## $ y(t) = \cos(2 \pi f t - 2\pi f 2) $
# ## $ y(t) = \cos(2 \pi f t + \phi) $

# %% [markdown]
# ## $ \phi =  -2 \pi f *2 $

# %%
-2*np.pi*0.2*2
# Out:
# -2.5132741228718345
